# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## **Objectives:**
#
# - Create a new Jupyter notebook
# - Review the lessons in this section of the course like languages, libraries and tools
# - Some Popular languages for Data Science are: Python, R, SQL, SCALA, JAVA C++ and Julia
# - Some Popular libraries for Data Science are: Pandas, NumPy, MatPlotlib, Seaborn, Scikit Learn and Keras
# - Create code and markdown cells

# %% [markdown]
# ## Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java
# 6. C++
# 7. Julia

# %% [markdown]
# ## Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Seaborn
# 5. SciKitLearn
# 6. Keras
# 7. Vegas
# 8. BigDL
# 9. ggPlot2

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter Notebook / Jupyter Lab|
# |RStudio|
# |Apache Zeppelin|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# 2+1
#
# 5*27+9
#
# 78/22

# %%
# This a simple arithmetic expression to mutiply then add integers

(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60

200/60 #minutos
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Ricardo G. Martínez Gaña
